# %% [markdown]
# <a href="https://colab.research.google.com/github/jclary-31/Wave_forecast_postprocessing/blob/main/Wave.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from datetime import date

today = date.today()
day=today-pd.Timedelta(days=1)
day=day.strftime("%Y%m%d")



doc='https://dd.weather.gc.ca/today/observations/doc/'

stations_file='swob-xml_marine_station_list.csv'

response=requests.get(doc+stations_file)
data=response.text.split('\r\n')

stations=pd.DataFrame(columns=data[0].split(','),
                      data=[row.split(',') for row in data[1:]])


#convert lat lon in float
stations['Latitude']=stations['Latitude'].astype('float')
stations['Longitude']=stations['Longitude'].astype('float')


#remove station with no position (having =0)
stations=stations[stations['Latitude']!=0]

#exlcude stations not in Atlantic
stations=stations[stations['Longitude'].astype('float') > -75]

#exclude test
stations=stations[~stations['EN name'].str.contains('TEST')]

stations
# Out:
#    #IATA              FR name              EN name Province AUTO/MAN  \
# 25            BANQUEREAU BANK      BANQUEREAU BANK       XX     AUTO
# 26          West Bay of Fundy    West Bay of Fundy       XX     AUTO
# 27          EAST SCOTIA SLOPE    EAST SCOTIA SLOPE       XX     AUTO
# 28            HALIFAX HARBOUR      HALIFAX HARBOUR       XX     AUTO
# 29               LA HAVE BANK         LA HAVE BANK       XX     AUTO
# 30             LAURENTIAN FAN       LAURENTIAN FAN       XX     AUTO
# 31                 MONT LOUIS           MONT LOUIS       XX     AUTO
# 32             NE BURGEO BANK       NE BURGEO BANK       XX     AUTO
# 33             NICKERSON BANK       NICKERSON BANK       XX     AUTO
# 34             SW GRAND BANKS       SW GRAND BANKS       XX     AUTO
# 35           TAIL OF THE BANK     TAIL OF THE BANK       XX     AUTO
# 38        East Chedabucto Bay  East Chedabucto Bay       XX     AUTO
# 39        West Chedabucto Bay  West Chedabucto Bay       XX     AUTO
#
#      Latitude  Longitude Elevation # ICAO    # WMO    # MSC DST Time STD Time  \
# 25  44.240200 -57.103200         0           44139  9300243
# 26  44.660557 -66.368612         0         4400490  9300300
# 27  42.261300 -61.998500         0           44137  9300355
# 28  44.501700 -63.402600         0           44258  9300400
# 29  42.504700 -64.071800         0           44150  9300450
# 30  42.992800 -57.958000         0           44141  9300587
# 31  49.539100 -65.710700         0           45138  9300620
# 32  47.266900 -57.335600         0           44255  9300630
# 33  46.443800 -53.391800         0           44251  9300635
# 34  44.251300 -53.633200         0           44138  9300658
# 35  42.868400 -51.466500         0           44140  9300720
# 38  45.445000 -60.953750         0         4400488  9302000
# 39  45.486867 -61.141033         0         4400489  9302001
#
#                                         Data Provider  \
# 25  Environment and Climate Change Canada (ECCC) i...
# 26  Environment and Climate Change Canada (ECCC) i...
# 27  Environment and Climate Change Canada (ECCC) i...
# 28  Environment and Climate Change Canada (ECCC) i...
# 29  Environment and Climate Change Canada (ECCC) i...
# 30  Environment and Climate Change Canada (ECCC) i...
# 31  Environment and Climate Change Canada (ECCC) i...
# 32  Environment and Climate Change Canada (ECCC) i...
# 33  Environment and Climate Change Canada (ECCC) i...
# 34  Environment and Climate Change Canada (ECCC) i...
# 35  Environment and Climate Change Canada (ECCC) i...
# 38  Environment and Climate Change Canada (ECCC) i...
# 39  Environment and Climate Change Canada (ECCC) i...
#
#                         Data Attribution Notice
# 25  Data provided by ECCC. All rights reserved.
# 26  Data provided by ECCC. All rights reserved.
# 27  Data provided by ECCC. All rights reserved.
# 28  Data provided by ECCC. All rights reserved.
# 29  Data provided by ECCC. All rights reserved.
# 30  Data provided by ECCC. All rights reserved.
# 31  Data provided by ECCC. All rights reserved.
# 32  Data provided by ECCC. All rights reserved.
# 33  Data provided by ECCC. All rights reserved.
# 34  Data provided by ECCC. All rights reserved.
# 35  Data provided by ECCC. All rights reserved.
# 38  Data provided by ECCC. All rights reserved.
# 39  Data provided by ECCC. All rights reserved.

# %%
import re

#exemple of directory
#https://dd.weather.gc.ca/20260113/WXO-DD/observations/swob-ml/marine/moored-buoys/20260113/
moored_dir='https://dd.weather.gc.ca/'+day+'/WXO-DD/observations/swob-ml/marine/moored-buoys/'

response=requests.get(moored_dir+day+'/')
moored_ids = re.findall(r'<a href="(\d+)/">', response.text)
moored_ids

#this is just to check existing id
# Out:
# ['4400137',
#  '4400139',
#  '4400150',
#  '4400258',
#  '4400488',
#  '4400489',
#  '4600004',
#  '4600036',
#  '4600131',
#  '4600132',
#  '4600145',
#  '4600146',
#  '4600181',
#  '4600184',
#  '4600185',
#  '4600204',
#  '4600205',
#  '4600206',
#  '4600207',
#  '4600208',
#  '4600303',
#  '4600304']

# %%
#match stations id nomenclature between observed buoys and the one registered in 'stations' dataframe
station_ids=[]
for i in range(len(stations)):
  id=stations['# WMO'].iloc[i]
  if len(id)==5:
    new_id=id[0:2]+'00'+id[2:]
  else:
    new_id=id
  station_ids.append(new_id)

stations['# WMO']=station_ids
stations['# WMO']
# Out:
# 25    4400139
# 26    4400490
# 27    4400137
# 28    4400258
# 29    4400150
# 30    4400141
# 31    4500138
# 32    4400255
# 33    4400251
# 34    4400138
# 35    4400140
# 38    4400488
# 39    4400489
# Name: # WMO, dtype: object

# %%
#available id
#from station, only keep row with # WMO existing in observations
stations=stations[stations['# WMO'].isin(moored_ids)]
stations
# Out:
#    #IATA              FR name              EN name Province AUTO/MAN  \
# 25            BANQUEREAU BANK      BANQUEREAU BANK       XX     AUTO
# 27          EAST SCOTIA SLOPE    EAST SCOTIA SLOPE       XX     AUTO
# 28            HALIFAX HARBOUR      HALIFAX HARBOUR       XX     AUTO
# 29               LA HAVE BANK         LA HAVE BANK       XX     AUTO
# 38        East Chedabucto Bay  East Chedabucto Bay       XX     AUTO
# 39        West Chedabucto Bay  West Chedabucto Bay       XX     AUTO
#
#      Latitude  Longitude Elevation # ICAO    # WMO    # MSC DST Time STD Time  \
# 25  44.240200 -57.103200         0         4400139  9300243
# 27  42.261300 -61.998500         0         4400137  9300355
# 28  44.501700 -63.402600         0         4400258  9300400
# 29  42.504700 -64.071800         0         4400150  9300450
# 38  45.445000 -60.953750         0         4400488  9302000
# 39  45.486867 -61.141033         0         4400489  9302001
#
#                                         Data Provider  \
# 25  Environment and Climate Change Canada (ECCC) i...
# 27  Environment and Climate Change Canada (ECCC) i...
# 28  Environment and Climate Change Canada (ECCC) i...
# 29  Environment and Climate Change Canada (ECCC) i...
# 38  Environment and Climate Change Canada (ECCC) i...
# 39  Environment and Climate Change Canada (ECCC) i...
#
#                         Data Attribution Notice
# 25  Data provided by ECCC. All rights reserved.
# 27  Data provided by ECCC. All rights reserved.
# 28  Data provided by ECCC. All rights reserved.
# 29  Data provided by ECCC. All rights reserved.
# 38  Data provided by ECCC. All rights reserved.
# 39  Data provided by ECCC. All rights reserved.

# %%
buoy_ids=stations['# WMO'].tolist()
buoy_ids.sort()
buoy_ids
# Out:
# ['4400137', '4400139', '4400150', '4400258', '4400488', '4400489']

# %%
## GET BUYOS observations! aka read xml real observations!
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET

#buoy_ids=stations['# WMO'].tolist()
#buoy_ids
i=-1

moored_dir='https://dd.weather.gc.ca/'+day+'/WXO-DD/observations/swob-ml/marine/moored-buoys/'
buyo_dir=moored_dir+day+'/'+str(buoy_ids[i])+'/'

#get all files in the targeted directory
def get_files(buyo_dir):
  response=requests.get(buyo_dir)
  response.text
  soup=BeautifulSoup(response.text,'html.parser')
  #print(soup.prettify())
  # Corrected method name to find_all and used a regex to find links to .grib2 files
  txt=soup.find_all('a', href=re.compile(r'\.xml$'))
  files=[]
  for row in txt:
    file=row['href']
    files.append(file)
  return files

files=get_files(buyo_dir)



# for nodes/etiquettes description see p74 et75 of the product user guide
# https://dd.weather.gc.ca/today/observations/doc/SWOB-ML_Product_User_Guide_v8.15_e.pdf
nodes_ofinterest=['wmo_id_extnd','stn_nam','date_tm','lat','long',
                  'avg_sig_wave_hgt_pst20mts',
                  'avg_sig_wave_pd_pst20mts',
                  'avg_wave_dir_pst20mts',
                  'avg_wnd_spd_pst10mts',
                  'avg_wnd_dir_pst10mts'
                  ]



def read_xml(response,nodes_ofinterest):

  # Define xml namespaces
  #### ECCC made its own xml format, which is very specific!
  #### if failed to dynamically extract xml namespaces but it should be constant
  xml_namespaces = {
      'om': 'http://www.opengis.net/om/1.0',
      'gml': 'http://www.opengis.net/gml',
      '': 'http://dms.ec.gc.ca/schema/point-observation/2.0'
      }


  xml_content=response.content
  tree = ET.fromstring(xml_content)

  #etiquettes=tree.findall('.//element',xml_namespaces)

  df=pd.DataFrame()#columns=nodes_ofinterest)
  for nodename in nodes_ofinterest:
    #find node with name 'nodename' that have 'element' as a child
    e=tree.find(f'.//element[@name="{nodename}"]',xml_namespaces)
    valu=e.get('value') if e is not None else None
    unit=e.get('uom') if e is not None else None
    if valu=='MSNG':
      valu=None
    #print(f'{nodename}: {valu} {unit}')
    q=pd.DataFrame(data=(nodename,valu,unit))
    df=pd.concat([df,q.T],axis=0,ignore_index=True)

  return df


def get_buoy(buyo_dir):
# read the xml file in the targeted directory
  files=get_files(buyo_dir)

  df=pd.DataFrame()
  for f in files:
    response=requests.get(buyo_dir+f)
    q=read_xml(response,nodes_ofinterest)
    df=pd.concat([df,q],ignore_index=True)

  df.columns=['name','value','unit']

  #convert the stuff into a dataframe with time as index
  Q=pd.DataFrame()
  names=df.name.unique()
  for nam in names:
    nam_unique=df[df.name==nam].unit.unique()
    #print(nam_unique)
    if len(nam_unique)!=1: # check unit consitcency across time
      print(f'warning: unit not consistent for {nam}')
    else:
      df_nam=df[df.name==nam]
      Q[nam]=df_nam.value.tolist()


  #convert data in numeric whenever possible
  for col in Q.columns:
    try:
      Q[col]=pd.to_numeric(Q[col])
    except:
      pass

  #create datetime after numeric conversion, if before, date_tm will be a strange number
  #print(Q['date_tm'][0])
  Q['date_tm']=pd.to_datetime(Q['date_tm'],format='ISO8601')#.dt.tz_localize(None)# localize (None) to remove UTC reference

  #finally rename columns
  # SW= significant wave
  easy_names=['buoy_id','name','time','lat','lon',
              'SW_Height',
              'SW_period',
              'SW_direction',
              'Wind_speed',
              'Wind_direction']

  zip_dict=dict(zip(nodes_ofinterest,easy_names))
  #print(zip_dict)
  Q.rename(columns=zip_dict,inplace=True)

  # return result as an xarray, which is way better than a dataframe (to me)
  ds=Q.drop(['name'],axis=1).set_index(['time','buoy_id','lat','lon']).to_xarray()
  ds=ds.squeeze(['lat','lon'])

  ##angle convention!!!
  # ocean data : wind direction is where it come from, butI dont find confirmation on swob product user
  # atmospheric model : wind direction is where the wind goes!!!!!! opposite direction of 'coming from' direction
  # both are in degrees clockwise from true North
  ds['Wind_direction']=(180+ ds['Wind_direction'])%360

  ###xml wind speed is in km/h whereas model and good practice is in m/s
  ds['Wind_speed']=ds['Wind_speed']*1000/3600

  return ds

ds=get_buoy(buyo_dir)
ds

####make lat and lon depend on buoy id !!!!!!!!!!!!!!!!!!
# Out:
# <xarray.Dataset> Size: 7kB
# Dimensions:         (time: 144, buoy_id: 1)
# Coordinates:
#   * time            (time) datetime64[ns, UTC] 1kB 2026-03-17 00:00:00+00:00 ...
#   * buoy_id         (buoy_id) int64 8B 4400489
#     lat             float64 8B 45.49
#     lon             float64 8B -61.14
# Data variables:
#     SW_Height       (time, buoy_id) float64 1kB nan nan nan nan ... nan nan nan
#     SW_period       (time, buoy_id) float64 1kB nan nan nan nan ... nan nan nan
#     SW_direction    (time, buoy_id) float64 1kB nan nan nan nan ... nan nan nan
#     Wind_speed      (time, buoy_id) float64 1kB 13.5 nan 13.69 ... 11.19 10.89
#     Wind_direction  (time, buoy_id) float64 1kB 335.0 nan 338.0 ... 41.0 40.0

# %%
#########just some check #### back and forth dataframe and xarray!
#### dataframe index become xarray dimensions
import xarray as xr

Q=ds.to_dataframe()
Q.reset_index(inplace=True)

z=xr.Dataset(
    data_vars=dict(SW_Height=(['time'],Q['SW_Height']),
                   SW_period=(['time'],Q['SW_period']),
                   SW_direction=(['time'],Q['SW_direction']),
    ),
    coords=dict(
        time=Q['time'],
        lon=Q['lon'].unique(),
        lat=Q['lat'].unique(),
        buoy_id=Q['buoy_id'].unique(),
    ),

)

#xr.concat([z,z],dim='buoy')

z.to_dataframe().to_xarray()#['time']#.dt.tz_localize('UTC')
# Out:
# <xarray.Dataset> Size: 5kB
# Dimensions:       (time: 144, lon: 1, lat: 1, buoy_id: 1)
# Coordinates:
#   * time          (time) datetime64[ns] 1kB 2026-03-17 ... 2026-03-17T23:50:00
#   * lon           (lon) float64 8B -61.14
#   * lat           (lat) float64 8B 45.49
#   * buoy_id       (buoy_id) int64 8B 4400489
# Data variables:
#     SW_Height     (time, lon, lat, buoy_id) float64 1kB nan nan nan ... nan nan
#     SW_period     (time, lon, lat, buoy_id) float64 1kB nan nan nan ... nan nan
#     SW_direction  (time, lon, lat, buoy_id) float64 1kB nan nan nan ... nan nan

# %%
import xarray as xr
z=xr.Dataset(
    data_vars=dict(SW_Height=(['time'],Q['SW_Height']),
                   SW_period=(['time'],Q['SW_period']),
                   SW_direction=(['time'],Q['SW_direction']),
                   Wind_speed=(['time'],Q['Wind_speed']),
                   Wind_direction=(['time'],Q['Wind_direction']),
    ),
    coords=dict(
        time=Q['time'],
        lon=Q['lon'].unique(),
        lat=Q['lat'].unique(),
        buoy_id=Q['buoy_id'].unique(),
    ),

)

#xr.concat([z,z],dim='buoy_id')

z.to_dataframe().to_xarray()

###converting xarray to dataframe to xarray back remove to 'UTC' time zone of time,why?
# Out:
# <xarray.Dataset> Size: 7kB
# Dimensions:         (time: 144, lon: 1, lat: 1, buoy_id: 1)
# Coordinates:
#   * time            (time) datetime64[ns] 1kB 2026-03-17 ... 2026-03-17T23:50:00
#   * lon             (lon) float64 8B -61.14
#   * lat             (lat) float64 8B 45.49
#   * buoy_id         (buoy_id) int64 8B 4400489
# Data variables:
#     SW_Height       (time, lon, lat, buoy_id) float64 1kB nan nan ... nan nan
#     SW_period       (time, lon, lat, buoy_id) float64 1kB nan nan ... nan nan
#     SW_direction    (time, lon, lat, buoy_id) float64 1kB nan nan ... nan nan
#     Wind_speed      (time, lon, lat, buoy_id) float64 1kB 13.5 nan ... 10.89
#     Wind_direction  (time, lon, lat, buoy_id) float64 1kB 335.0 nan ... 40.0

# %%
##############another quick test about data format. making dictionary instead of xarray.
##############ok for one buoy but not sure it is efficient for multiple buoy

#import json
import numpy as np # Import numpy
import matplotlib.pyplot as plt
#import matplotlib.dates as mdates # Import matplotlib.dates


#convert to xml?
#z.to_dataframe().to_json(orient='records')
zz=z.to_dataframe()
zz.reset_index(inplace=True)

dic=dict()
# Convert numpy types to standard Python types before assigning
dic['buoy_id']=int(zz.buoy_id.unique()[0])
dic['lat']=float(zz.lat.unique()[0])
dic['lon']=float(zz.lon.unique()[0])
dic['time']=zz.time.unique().tolist() #
dic['SW_Height']=zz.SW_Height.values.tolist()
dic['SW_period']=zz.SW_period.values.tolist()
dic['SW_direction']=zz.SW_direction.values.tolist() #
dic['Wind_direction']=zz.Wind_direction.values.tolist()
dic['Wind_speed']=zz.Wind_speed.values.tolist()

# Use json.dumps to convert the dictionary to a JSON string
#json.dumps(dic)
#dic['time'],dic['SW_Height']



ax = plt.gca()
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
plt.setp(ax.get_xticklabels(), rotation=45, ha="right")
plt.plot(dic['time'],dic['Wind_direction'])
plt.plot(z['time'],z['Wind_direction'],'.')

# %%
#check issue with buoy in Chedabucto Bay ; aka 2 last buyo in buoyid (i=4 and i=5)

#day='20251216'
#above data frame is just for one day! and one buoy!
moored_dir='https://dd.weather.gc.ca/'+day+'/WXO-DD/observations/swob-ml/marine/moored-buoys/'

bu_id='4400139'
print(f'data statistics for day {day} at buoy {bu_id}')
buyo_dir=moored_dir+day+'/'+bu_id+'/'
z=get_buoy(buyo_dir).to_dataframe()
print(z[['SW_Height','SW_period','SW_direction']].describe())
#vec.append(z)

#-> it seems buoy in Chdeabucto  bay give info every 10 mn and not every hour
# + there is no wave measurement... because winter and near shore???



#####-> remove id 4400488 and 4400489 for further use ; see in spring
#but data exists here https://www.ndbc.noaa.gov/station_page.php?station=44488 ...
# see later
if '4400488' in buoy_ids:
  buoy_ids.remove('4400488')
  buoy_ids.remove('4400489')
  stations=stations[stations['# WMO']!='4400488']
  stations=stations[stations['# WMO']!='4400489']


stations
# Out:
# data statistics for day 20260317 at buoy 4400139
#        SW_Height  SW_period  SW_direction
# count  24.000000  24.000000     24.000000
# mean    2.541667   7.108333    197.583333
# std     0.557102   0.810752      8.781981
# min     1.500000   5.900000    181.000000
# 25%     2.300000   6.350000    191.500000
# 50%     2.400000   7.200000    200.500000
# 75%     2.925000   7.600000    203.000000
# max     3.500000   8.700000    213.000000
#    #IATA            FR name            EN name Province AUTO/MAN  Latitude  \
# 25          BANQUEREAU BANK    BANQUEREAU BANK       XX     AUTO   44.2402
# 27        EAST SCOTIA SLOPE  EAST SCOTIA SLOPE       XX     AUTO   42.2613
# 28          HALIFAX HARBOUR    HALIFAX HARBOUR       XX     AUTO   44.5017
# 29             LA HAVE BANK       LA HAVE BANK       XX     AUTO   42.5047
#
#     Longitude Elevation # ICAO    # WMO    # MSC DST Time STD Time  \
# 25   -57.1032         0         4400139  9300243
# 27   -61.9985         0         4400137  9300355
# 28   -63.4026         0         4400258  9300400
# 29   -64.0718         0         4400150  9300450
#
#                                         Data Provider  \
# 25  Environment and Climate Change Canada (ECCC) i...
# 27  Environment and Climate Change Canada (ECCC) i...
# 28  Environment and Climate Change Canada (ECCC) i...
# 29  Environment and Climate Change Canada (ECCC) i...
#
#                         Data Attribution Notice
# 25  Data provided by ECCC. All rights reserved.
# 27  Data provided by ECCC. All rights reserved.
# 28  Data provided by ECCC. All rights reserved.
# 29  Data provided by ECCC. All rights reserved.

# %%
import xarray as xr

#this is for a given day!
vec=[]
for i in range(len(buoy_ids)):
  buoy_dir=moored_dir+day+'/'+str(buoy_ids[i])+'/'
  print(buoy_dir)
  obs=get_buoy(buoy_dir)

  vec.append(obs)

ds_buoy=xr.concat(vec,dim='buoy_id',join='outer')
ds_buoy['time']=pd.to_datetime(ds_buoy['time']).tz_localize('UTC')
ds_buoy

#buoy_ids
# Out:
# https://dd.weather.gc.ca/20260317/WXO-DD/observations/swob-ml/marine/moored-buoys/20260317/4400137/
# https://dd.weather.gc.ca/20260317/WXO-DD/observations/swob-ml/marine/moored-buoys/20260317/4400139/
# https://dd.weather.gc.ca/20260317/WXO-DD/observations/swob-ml/marine/moored-buoys/20260317/4400150/
# https://dd.weather.gc.ca/20260317/WXO-DD/observations/swob-ml/marine/moored-buoys/20260317/4400258/
# /tmp/ipykernel_232/2831866270.py:12: FutureWarning: In a future version of xarray the default value for coords will change from coords='different' to coords='minimal'. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set coords explicitly.
#   ds_buoy=xr.concat(vec,dim='buoy_id',join='outer')
# <xarray.Dataset> Size: 4kB
# Dimensions:         (time: 24, buoy_id: 4)
# Coordinates:
#   * time            (time) datetime64[ns, UTC] 192B 2026-03-17 00:05:00+00:00...
#   * buoy_id         (buoy_id) int64 32B 4400137 4400139 4400150 4400258
#     lat             (buoy_id) float64 32B 42.26 44.24 42.51 44.5
#     lon             (buoy_id) float64 32B -62.0 -57.1 -64.02 -63.4
# Data variables:
#     SW_Height       (time, buoy_id) float64 768B 2.4 1.5 2.9 3.2 ... 3.5 4.5 4.7
#     SW_period       (time, buoy_id) float64 768B 6.6 6.6 7.3 ... 8.7 10.0 10.3
#     SW_direction    (time, buoy_id) int64 768B 157 209 158 180 ... 207 209 202
#     Wind_speed      (time, buoy_id) float64 768B 10.81 11.11 ... 13.89 10.69
#     Wind_direction  (time, buoy_id) int64 768B 348 317 348 357 ... 96 3 74 48

# %%
exple=ds_buoy.isel(buoy_id=0)

ax = plt.gca()

plt.setp(ax.get_xticklabels(), rotation=45, ha="right")
plt.plot(exple['time'],exple['Wind_direction'])


###compare with https://www.ndbc.noaa.gov/data/realtime2/44137.txt ???

# %%
#!!!!!!!!!!!!!!!!!!!!

#buyos recent data also exist at NOAA website
# eg george bank buoy  past 45 days data are here : https://www.ndbc.noaa.gov/data/realtime2/44011.txt
#nomenclature https://www.ndbc.noaa.gov/faq/measdes.shtml
#-> noaa buyo ; contain thehere Wdir is  Wind direction (the direction the wind is coming from in degrees clockwise from true N)

##0/ compare angle
### 1/ make a code later to upload an exemple with specific features
### 2/ list buoy in the area
### 3/ compare obs from moored buoy registred by ECCC with the same boyu in NOAA database.
### not important right now

# %%
                  #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


                  #PART 2 GET regional model wave forecast



                  #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
###see interactives map https://eccc-msc.github.io/msc-animet/?layers=HRDPS.CONTINENTAL_UU;0.75;0;1;0;1,HRDPS.CONTINENTAL_WD;0.75;0;1;0;1&extent=-10159787,2029488,-2552853,8092049&overlays=Boundaries&range=48,0,l,PT1H
###00 mean midnight but model give output every 6 hours
model_dir='https://dd.weather.gc.ca/'+day+'/WXO-DD/model_rdwps/national/2.5km/00/'


horizon=24# in hour (model)

grib2_dir = 'data_grib2'

#see variable description in the list at the bottom of
# https://eccc-msc.github.io/open-data/msc-data/nwp_rdwps/readme_rdwps-datamart_en/
var_ofinterest=['WVHGT','HTSGW','WVDIR','PPERWW','UGRD','VGRD']


#get all files in the targeted directory
def get_grib2_files(target_dir,var_ofinterest,horizon):
  response=requests.get(target_dir)
  soup=BeautifulSoup(response.text,'html.parser')
  #print(soup.prettify())

  # use find_all and a regex expression to find all .grib2 files
  txt=soup.find_all('a', href=re.compile(r'\.grib2$'))
  files=[]
  for row in txt:
    file=row['href']
    files.append(file)

  # remove file with forecast greater than horizon
  files0=files.copy() # need a copy to increment
  for file in files0:
    reach=file.split('_PT')[1][:3]
    if int(reach) >= horizon:
      files.remove(file)

  ##keep only files with wanted variables
  grib2_list=[]
  for file in files:
    for var in var_ofinterest:
      if var in file:
        grib2_list.append(file)

  return grib2_list


grib2_files=get_grib2_files(model_dir,var_ofinterest,horizon)
grib2_files[:20]
# Out:
# ['20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT000H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT001H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT002H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT003H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT004H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT005H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT006H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT007H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT008H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT009H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT010H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT011H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT012H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT013H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT014H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT015H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT016H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT017H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT018H.grib2',
#  '20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT019H.grib2']

# %%
import urllib
#import xarray as xr
import os



# Create a directory to store the GRIB2 files if it doesn't exist
if not os.path.exists(grib2_dir):
  os.makedirs(grib2_dir)

# create subdir for a given day!
if not os.path.exists(os.path.join(grib2_dir,day)):
  os.makedirs(os.path.join(grib2_dir,day),exist_ok=True)


def download_grib2_files(grib2_files):
  for file in grib2_files:
    full_url = model_dir + file
    # Construct the full output path, including potential subdirectories based on the file name.
    output_path = os.path.join(grib2_dir, file[:8], file)


    if os.path.exists(output_path):
      print(f"{file} already exists. Skipping download.")
    else:
      print(f"Downloading: {full_url} to {output_path}")
      try:
        response = requests.get(full_url)
        response.raise_for_status() # Raise an HTTPError for bad responses
        with open(output_path, 'wb') as f:
          f.write(response.content)

      except requests.exceptions.HTTPError as err:
        print(f"HTTP error occurred for {file}: {err}")
      except requests.exceptions.RequestException as err:
        print(f"Other request error occurred for {file}: {err}")


download_grib2_files(grib2_files)
# Out:
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT000H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT000H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT001H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT001H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT002H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT002H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT003H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT003H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT004H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT004H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT005H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT005H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT006H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT006H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT007H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT007H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT008H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT008H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT009H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT009H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT010H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT010H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT011H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT011H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT012H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT012H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT013H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT013H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT014H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT014H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT015H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT015H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT016H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT016H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT017H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT017H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT018H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT018H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT019H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT019H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT020H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT020H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT021H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT021H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT022H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT022H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT023H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_HTSGW_Sfc_RLatLon0.0225_PT023H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT000H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT000H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT001H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT001H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT002H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT002H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT003H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT003H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT004H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT004H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT005H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT005H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT006H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT006H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT007H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT007H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT008H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT008H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT009H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT009H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT010H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT010H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT011H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT011H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT012H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT012H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT013H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT013H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT014H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT014H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT015H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT015H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT016H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT016H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT017H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT017H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT018H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT018H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT019H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT019H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT020H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT020H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT021H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT021H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT022H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT022H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT023H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_PPERWW_Sfc_RLatLon0.0225_PT023H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT000H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT000H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT001H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT001H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT002H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT002H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT003H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT003H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT004H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT004H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT005H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT005H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT006H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT006H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT007H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT007H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT008H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT008H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT009H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT009H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT010H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT010H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT011H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT011H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT012H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT012H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT013H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT013H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT014H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT014H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT015H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT015H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT016H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT016H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT017H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT017H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT018H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT018H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT019H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT019H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT020H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT020H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT021H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT021H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT022H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT022H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT023H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT023H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT000H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT000H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT001H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT001H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT002H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT002H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT003H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT003H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT004H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT004H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT005H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT005H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT006H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT006H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT007H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT007H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT008H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT008H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT009H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT009H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT010H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT010H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT011H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT011H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT012H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT012H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT013H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT013H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT014H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT014H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT015H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT015H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT016H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT016H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT017H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT017H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT018H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT018H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT019H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT019H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT020H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT020H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT021H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT021H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT022H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT022H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT023H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_VGRD_AGL-10m_RLatLon0.0225_PT023H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT000H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT000H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT001H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT001H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT002H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT002H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT003H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT003H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT004H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT004H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT005H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT005H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT006H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT006H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT007H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT007H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT008H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT008H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT009H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT009H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT010H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT010H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT011H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT011H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT012H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT012H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT013H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT013H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT014H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT014H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT015H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT015H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT016H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT016H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT017H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT017H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT018H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT018H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT019H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT019H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT020H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT020H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT021H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT021H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT022H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT022H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT023H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVDIR_Sfc_RLatLon0.0225_PT023H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT000H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT000H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT001H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT001H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT002H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT002H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT003H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT003H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT004H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT004H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT005H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT005H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT006H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT006H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT007H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT007H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT008H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT008H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT009H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT009H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT010H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT010H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT011H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT011H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT012H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT012H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT013H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT013H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT014H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT014H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT015H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT015H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT016H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT016H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT017H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT017H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT018H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT018H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT019H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT019H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT020H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT020H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT021H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT021H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT022H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT022H.grib2
# Downloading: https://dd.weather.gc.ca/20260317/WXO-DD/model_rdwps/national/2.5km/00/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT023H.grib2 to data_grib2/20260317/20260317T00Z_MSC_RDWPS_WVHGT_Sfc_RLatLon0.0225_PT023H.grib2

# %%
import os
import importlib

# Install cfgrib for xarray to open GRIB2 files
try :
  importlib.import_module('cfgrib')
  print('cfgrib already installed')
except ImportError:
  print('installing cfgrib')
  # !pip install cfgrib

# import xarray AFTER installing cfgrib to ensure cfgrib engine is ok
import xarray as xr


def remove_idxfiles():
#any grib2 load create an idx file, which need to be
#removed before listing existingfiles
  subdir= os.path.join(grib2_dir,day)
  for file in os.listdir(subdir):
    if file.endswith('.idx'):
      os.remove(os.path.join(subdir,file))




def load_grib(file):

# Construct the full path to the GRIB files
  day=file[:8]
  file_path = os.path.join(grib2_dir, day,file)

# Check if the file exists before attempting to open it
  if os.path.exists(file_path):
    # Open the dataset using xarray
    ds = xr.open_dataset(file_path, engine="cfgrib",
                         #filter_by_keys={'typeOfLevel': 'surface'}# U,V is at 10m!
    )
    #add a utc time zone, missing when loading
    #in those grib2 'time is time at which forecast is done
    #and valid time is time at which forecast is done + step
    #ds['time']=pd.to_datetime(ds['valid_time'].values).tz_localize('UTC')#
    # fail to give time(ns,utc)!
    # I have to convert stfrtime and add 'Z' for zulu and then convert back
    valid_time=pd.Series(ds['valid_time'].values).dt.strftime('%Y-%m-%d %H:%M:%SZ')
    ds['time']=pd.to_datetime(valid_time.values,format='ISO8601')#same format as buoy!

    #ds.set_coords('time')##,inplace=True)
    #ds=ds.expand_dims(dim='time' )
    #ts = ds['time'].dt.tz_localize(utc)#[0].item()

    # Ensure the timestamp is in UTC
    #if ts.tz is not None:
        #ts = ts.tz_convert('UTC')
    #print(ts)

    #remove not necessary coords
    ds=ds.drop_vars(['step','valid_time'])

    if'surface' in ds.coords:
      ds=ds.drop_vars('surface')
    if 'heightAboveGround' in ds.coords:
      ds=ds.drop_vars('heightAboveGround')
    # for now remove idxfile every time, could be when everything is loaded
    remove_idxfiles()

  else:
    print(f"Error: File not found at {file_path}")

  return ds




test_file=grib2_files[1]
#test_file.replace('HTSGW','UGRD')

#test a file with wind data
#https://eccc-msc.github.io/open-data/msc-data/nwp_rdwps/readme_rdwps-datamart_en/
#u and v components of the wind vector are to be resolved relative to the defined grid,
# in the direction of increasing i and j coordinates.

for file in grib2_files:
  if 'UGRD' in file:
    test_file=file
    break

print(test_file)

####load one file with U speed
ds_u=load_grib(test_file)

###load one file with V spead
test_file=test_file.replace('UGRD','VGRD')
ds_v=load_grib(test_file)


ds_u.u10.attrs
# Out:
# cfgrib already installed
# 20260317T00Z_MSC_RDWPS_UGRD_AGL-10m_RLatLon0.0225_PT000H.grib2
# {'GRIB_paramId': 165,
#  'GRIB_dataType': 'af',
#  'GRIB_numberOfPoints': 3261296,
#  'GRIB_typeOfLevel': 'heightAboveGround',
#  'GRIB_stepUnits': 1,
#  'GRIB_stepType': 'instant',
#  'GRIB_gridType': 'rotated_ll',
#  'GRIB_uvRelativeToGrid': 1,
#  'GRIB_NV': 0,
#  'GRIB_Nx': 2536,
#  'GRIB_Ny': 1286,
#  'GRIB_angleOfRotationInDegrees': 0.0,
#  'GRIB_cfName': 'eastward_wind',
#  'GRIB_cfVarName': 'u10',
#  'GRIB_gridDefinitionDescription': 'Rotated latitude/longitude',
#  'GRIB_iDirectionIncrementInDegrees': 0.0225,
#  'GRIB_iScansNegatively': 0,
#  'GRIB_jDirectionIncrementInDegrees': 0.0225,
#  'GRIB_jPointsAreConsecutive': 0,
#  'GRIB_jScansPositively': 1,
#  'GRIB_latitudeOfFirstGridPointInDegrees': -12.2575,
#  'GRIB_latitudeOfLastGridPointInDegrees': 16.655001,
#  'GRIB_latitudeOfSouthernPoleInDegrees': -36.08852,
#  'GRIB_longitudeOfFirstGridPointInDegrees': 345.22329,
#  'GRIB_longitudeOfLastGridPointInDegrees': 42.260796,
#  'GRIB_longitudeOfSouthernPoleInDegrees': 245.305142,
#  'GRIB_missingValue': 3.4028234663852886e+38,
#  'GRIB_name': '10 metre U wind component',
#  'GRIB_shortName': '10u',
#  'GRIB_units': 'm s**-1',
#  'long_name': '10 metre U wind component',
#  'units': 'm s**-1',
#  'standard_name': 'eastward_wind'}

# %%
#import matplotlib.pyplot as plt
del ds
ds=xr.merge([ds_u.squeeze('time'),ds_v.squeeze('time')],join='inner',compat='no_conflicts' )
ds['Wind_amp']=np.sqrt(ds['u10']**2+ds['v10']**2)

# I just want a small area to check  u,v
bbox={
    'min_lat':40,
    'max_lat':50,
    'min_lon':-70,
    'max_lon':-55,
}


ds = ds.where(
      (ds.latitude >= bbox['min_lat']) &
      (ds.latitude <= bbox['max_lat']) &
      (ds.longitude >= bbox['min_lon']) &
      (ds.longitude <= bbox['max_lon']),
      ).dropna('x', how='all')\
      .dropna('y', how='all') #drop x y where all lign/row is nan


fig,ax=plt.subplots(1,2,figsize=(12,5))

ds['longitude'].plot(ax=ax[0])
ds['latitude'].plot(ax=ax[1])
#ax[0,0].set_title('u10')
#ax[0,1].set_title('v10')
ax[0].set_title('longitude')
ax[1].set_title('latitude')
#
# ds.plot.quiver(x='longitude',y='latitude',u='u10',v='v10',
#                aspect='equal',size=10,
#                )
# Out:
# Text(0.5, 1.0, 'latitude')

# %%
#########FROM ABOVE figure, axis are clearly rotated. No rotation would mean longitude is aligned with x, and latitude would be aligned with y
######### ALSO, one can see that rotation angle is about 40-45 degree,
## here I made a code to better compute this angle, but I am not sure 100%

def compute_curvilign_angle(ds):
  '''
  find local angle of rotation
  see definitions on wiki https://en.wikipedia.org/wiki/Curvilinear_coordinates
  and https://gis.stackexchange.com/questions/10808/manually-transforming-rotated-lat-lon-to-regular-lat-lon/14445#14445
  #not sure at 100%
  '''

  #(x,) is the 'destination' grid (true North, true East)
  Lat  = ds.latitude.values
  Lon  = ds.longitude.values

  #convert degree in radians
  Lat=np.deg2rad(Lat)
  Lon=np.deg2rad(Lon)


  #find local increasing direction ;  central differences
  dy_y = Lat[:, 2:] - Lat[:, :-2]
  dx_y = Lon[:, 2:] - Lon[:, :-2]


  y_c  = Lat[:, 1:-1]  # center latitude
  #print(np.mean(y_c), np.std(y_c)) #slights change over the domain

  # east/north components of y-direction
  dyE = dx_y * np.cos(y_c)
  dyN = dy_y

  # By definition :
  # cos theta= xrotated/x_norotation
  # sin theta= yrotated/y_norotation
  # so, theta= arctan(...)
  theta = np.arctan2(dyN, dyE)  # #atan2(y,x)

  #convert back to degrees (in math convention!)
  theta=np.rad2deg(theta)

  return theta

theta=compute_curvilign_angle(ds)


print(theta.min(),theta.max(), theta.mean())


#for theta, 1 point is lost is in first and last y, due dy_y and dx_y definition
X=ds['longitude'].values[:,1:-1]
Y=ds['latitude'].values[:,1:-1]

newX=np.cos(np.radians(theta))*X - np.sin(np.radians(theta))*Y
newY=+np.sin(np.radians(theta))*X + np.cos(np.radians(theta))*Y


fig,ax=plt.subplots(2,2,figsize=(8,8))
ax[0,0].contourf(X)
ax[0,1].contourf(Y)
ax[0,0].set_title('X')
ax[0,1].set_title('Y')
ax[1,0].contourf(newX)
ax[1,1].contourf(newY)
ax[1,0].set_title('newX')
ax[1,1].set_title('newY')
plt.show()


###something wrong here !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! X should increase according to x axsis no?
# Out:
# -49.07507181585581 -31.193661322312664 -40.25870287042398

# %%
from numpy._core.defchararray import title
#########Rotation!

def speed_rotation(ds,angle):
  rot=np.deg2rad(angle)
  Ugrid=ds['u10']
  Vgrid=ds['v10']

  #see rotation matrix https://en.wikipedia.org/wiki/Rotation_matrix#In_two_dimensions
  Uearth = np.cos(rot)*Ugrid - np.sin(rot)*Vgrid
  Vearth = np.sin(rot)*Ugrid + np.cos(rot)*Vgrid
  ds['U_rot']=Uearth
  ds['V_rot']=Vearth
  return ds

#ds['Wind_amp']=np.sqrt(ds['U']**2+ds['V']**2)

ds=speed_rotation(ds,theta.mean())





fig,ax=plt.subplots(2,2,figsize=(12,12))
np.rad2deg(np.arctan2(ds['v10'],ds['u10'])).plot(ax=ax[0,0],x='longitude',y='latitude',)
np.rad2deg(np.arctan2(ds['V_rot'],ds['U_rot'])).plot(ax=ax[0,1],x='longitude',y='latitude',)
ax[0,0].set_title('wind direction, before rotation')
ax[0,1].set_title('wind direction, after rotation')


###those angle are in math convention! (counterclockwise+ 0at east) + this is where the wind go
# buoy normally give incoming direction in geographical convention!
step=16
ds.isel(x=slice(None,None,step), y=slice(None,None,step))\
  .plot.quiver(x='longitude',y='latitude',
               u='u10',v='v10',
               #aspect='equal',#size=8,
               width=0.0025*2 ,headaxislength=2,headlength=4,headwidth=4,
                scale=150,
               ax=ax[1,0]
               )

ds.isel(x=slice(None,None,step), y=slice(None,None,step))\
  .plot.quiver(x='longitude',y='latitude',
               u='U_rot',v='V_rot',
               width=0.0025*2 ,headaxislength=2,headlength=4,headwidth=4,
                scale=150,
               ax=ax[1,1]
               )

ax[1,0].set_title('before rotation')
ax[1,1].set_title('after rotation')

print(ds.time)
  #!!!compare quiver with
  #https://eccc-msc.github.io/msc-animet/?layers=HRDPS.CONTINENTAL_UU;0.75;0;1;0;1,HRDPS.CONTINENTAL_WD;0.75;0;1;0;1&extent=-10159787,2029488,-2552853,8092049&overlays=Boundaries&range=48,0,l,PT1H
# Out:
# <xarray.DataArray 'time' ()> Size: 8B
# array('2026-03-17T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 8B 2026-03-17

# %%
# !pip install cartopy
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

print('Install cartopy for prettier projection')
# Out:
# Requirement already satisfied: cartopy in /usr/local/lib/python3.12/dist-packages (0.25.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.0.2)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.10.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.1.2)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from cartopy) (26.0)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.0.3)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj>=3.3.1->cartopy) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Install cartopy for prettier projection

# %%
###I got a problem with colorbar...

# Get the key variable
key=list(ds.keys())[2]
print(key)


# Create a figure and an axes object with a PlateCarree projection
#plt.figure(figsize=(10, 8))
fig,ax=plt.subplots(1,figsize=(12,12),subplot_kw={'projection':ccrs.PlateCarree()})

# Plot the data
# xarray's plot method integrates well with cartopy for geographical plotting
ds[key].plot(ax=ax,
                transform=ccrs.PlateCarree(),
                x='longitude',
                y='latitude',
                cmap='viridis',
                # cbar_kwargs={'label': '',
                #              'orientation' : 'horizontal'}
             )

# Add map features
ax.coastlines()
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)


###those angle are in math convention! (counterclockwise+ 0at east) + this is where the wind go
# buoy normally give incoming direction in geographical convention!
step=20
ds.isel(x=slice(None,None,step), y=slice(None,None,step))\
  .plot.quiver(x='longitude',y='latitude',
               u='U_rot',v='V_rot',
               #aspect='equal',size=8,
               width=0.0025 ,headaxislength=2,headlength=4,headwidth=4,
               scale=150,ax=ax,
               cbar_kwargs={'label': 'm/s',
                          'orientation' : 'horizontal','location':'bottom'}
               )


# Add buoy locations
ax.scatter(stations['Longitude'], stations['Latitude'],
           transform=ccrs.PlateCarree(),
           color='red', marker='o', s=50, label='Buoys')
for index, row in stations.iterrows():
    ax.text(row['Longitude'] + 0.1,
            row['Latitude'] + 0.1,
            row['EN name'],
            transform=ccrs.PlateCarree(),
            fontsize=9, color='red')


# Set title
ax.set_title(key+'   '+ str(ds.time.values)[:-13])

bbox={
    'min_lat':40-.5,
    'max_lat':50+.5,
    'min_lon':-70-.5,
    'max_lon':-55+.5,
}
# Recenter the figure using the bbox
ax.set_extent([bbox['min_lon'],
               bbox['max_lon'],
               bbox['min_lat'],
               bbox['max_lat']],
               crs=ccrs.PlateCarree())

#fig.colorbar(ds[key].plot(),ax=ax,label='m/s',location='bottom')


fig.savefig('example_locationandwind.jpg')
# Out:
# Wind_amp

# %%
####  THIS IS a test to see how dropna work with xarray dataset


####dropna threshold example

temperature = [
 [0, 4, 2, 9],
 [np.nan, np.nan, np.nan, np.nan],
 [np.nan, np.nan, 2, 0],
 [np.nan, 1, 0, 0],
       ]

da = xr.DataArray(
   data=temperature,
   dims=["Y", "X"],
   coords=dict(
   lat=("Y", np.array([-20.0, -20.25, -20.50, -20.75])),
   lon=("X", np.array([10.0, 10.25, 10.5, 10.75])),
),
)

da.dropna(dim='X',how='all',thresh=1+1) # if less than 2 value in a columns, remove the column
# Out:
# <xarray.DataArray (Y: 4, X: 3)> Size: 96B
# array([[ 4.,  2.,  9.],
#        [nan, nan, nan],
#        [nan,  2.,  0.],
#        [ 1.,  0.,  0.]])
# Coordinates:
#     lat      (Y) float64 32B -20.0 -20.25 -20.5 -20.75
#     lon      (X) float64 24B 10.25 10.5 10.75
# Dimensions without coordinates: Y, X

# %%
####note create UGRID, VGRD are on different location
#### because of that I added a threshold on the dropna in x direction
#### but this is just a fix

var_name='WVDIR' #this is var name of previous example


def get_grib2_specificdata(day,var_name,bbox=None):

  files_saved=os.listdir(grib2_dir+'/'+day+'/')
  files_saved.sort()

  ds_var=[]
  for file in files_saved:
    if var_name in file:
      ds=load_grib(file)
      #print(f'download {file}')
      ds_var.append(ds)

  ds=xr.concat(ds_var, dim='time',
               #combine='nested'
               coords='different',compat='equals',
               data_vars='all'
               )
  #ds=xr.combine_by_coords(ds_var)
  #ds=xr.combine_nested(ds_var,concat_dim='time')

  #crop here as I will use this function a lot
  if bbox is not None:
    ds = ds.where(
          (ds.latitude >= bbox['min_lat']) &
          (ds.latitude <= bbox['max_lat']) &
          (ds.longitude >= bbox['min_lon']) &
          (ds.longitude <= bbox['max_lon']),
          ).dropna('x', how='all',thresh=50)#\
           #.dropna('y', how='all',thresh=50) #drop x y where all lign/row is nan
  #dropna in y create inconsistencies in grid siez,.... because?
  return ds


bbox={
    'min_lat':35,
    'max_lat':50,
    'min_lon':-75,
    'max_lon':-40,
}

# DS_cropped = DS.where(
#     (DS.latitude >= min_lat) & (DS.latitude <= max_lat) &
#     (DS.longitude >= min_lon) & (DS.longitude <= max_lon),
#     drop=True
# ).dropna('x', how='all').dropna('y', how='all') # Drop rows/columns that are all NaN after filtering


ds=get_grib2_specificdata(day,var_name,bbox)
ds
#ds['time']
# Out:
# <xarray.Dataset> Size: 90MB
# Dimensions:    (time: 24, y: 1286, x: 625)
# Coordinates:
#   * time       (time) datetime64[ns, UTC] 192B 2026-03-17 00:00:00+00:00 ... ...
#     latitude   (y, x) float64 6MB 34.8 34.79 34.78 34.77 ... 47.92 47.9 47.89
#     longitude  (y, x) float64 6MB -80.45 -80.42 -80.4 ... -40.84 -40.82 -40.8
# Dimensions without coordinates: y, x
# Data variables:
#     wvdir      (time, y, x) float32 77MB nan nan nan nan ... 250.2 251.5 252.8
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             cwao
#     GRIB_centreDescription:  Canadian Meteorological Service - Montreal
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             Canadian Meteorological Service - Montreal
#     history:                 2026-03-18T01:16 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
def get_grib2_alldata(day,bbox=None):

  files_saved=os.listdir(grib2_dir+'/'+day+'/')
  files_saved.sort()

  x=[fil.split('_')[3] for fil in files_saved]
  var_available=list(set(x))

  Allds=[]
  for var in var_available:
    print(f'getting {var}')
    X=get_grib2_specificdata(day,var,bbox)
    Allds.append(X)
    print(f'{X.sizes}')
  ### concat in time only!!! as concat create a new dimension
  ### here use merge function
  Allds=xr.merge(Allds,join='inner',compat='no_conflicts' )
  return Allds

DS=get_grib2_alldata(day,bbox)
DS

#DS.step/60/60/1e9# step is in nanoseconds ; division give it in hour

##pp1d, see https://codes.ecmwf.int/grib/param-db/140231
# Out:
# getting HTSGW
# Frozen({'time': 24, 'y': 1286, 'x': 625})
# getting PPERWW
# Frozen({'time': 24, 'y': 1286, 'x': 625})
# getting VGRD
# Frozen({'time': 24, 'y': 1286, 'x': 625})
# getting UGRD
# Frozen({'time': 24, 'y': 1286, 'x': 625})
# getting WVHGT
# Frozen({'time': 24, 'y': 1286, 'x': 625})
# getting WVDIR
# Frozen({'time': 24, 'y': 1286, 'x': 625})
# <xarray.Dataset> Size: 476MB
# Dimensions:    (time: 24, y: 1286, x: 625)
# Coordinates:
#   * time       (time) datetime64[ns, UTC] 192B 2026-03-17 00:00:00+00:00 ... ...
#     latitude   (y, x) float64 6MB 34.8 34.79 34.78 34.77 ... 47.92 47.9 47.89
#     longitude  (y, x) float64 6MB -80.45 -80.42 -80.4 ... -40.84 -40.82 -40.8
# Dimensions without coordinates: y, x
# Data variables:
#     swh        (time, y, x) float32 77MB nan nan nan nan ... 4.165 4.164 4.163
#     pp1dw      (time, y, x) float32 77MB nan nan nan nan ... 8.144 8.987 9.829
#     v10        (time, y, x) float32 77MB nan nan nan nan ... 11.33 11.3 11.27
#     u10        (time, y, x) float32 77MB nan nan nan nan ... 1.497 1.55 1.602
#     shww       (time, y, x) float32 77MB nan nan nan nan ... 2.03 2.039 2.049
#     wvdir      (time, y, x) float32 77MB nan nan nan nan ... 250.2 251.5 252.8
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             cwao
#     GRIB_centreDescription:  Canadian Meteorological Service - Montreal
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             Canadian Meteorological Service - Montreal
#     history:                 2026-03-18T01:16 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
#DS.keys()
#data existing for buoy           model                               model
              # 'SW_Height',      WVHGT                              shww https://codes.ecmwf.int/grib/param-db/140234
              # 'SW_period',      PPERWW                             pp1dw https://codes.ecmwf.int/grib/param-db/140231
              # 'SW_direction',   WVDIR                              wvdir https://codes.ecmwf.int/grib/param-db/260232
              # 'Wind_speed',     u,v cartesian
              # 'Wind_dir'        u,v cartesian
              #   None            HTSGW (total heigh wind+swell)     swh https://codes.ecmwf.int/grib/param-db/140229


### correct wind because of coord rotation to real North

theta=compute_curvilign_angle(DS)


DS=speed_rotation(DS,np.mean(theta)) # supposing 40 as rotation angle

grib2_rename_dic={
                'shww':'SW_Height',
                'pp1dw':'SW_period',
                'wvdir':'SW_direction',
                'U_rot':'Wind_U',
                'V_rot':'Wind_V',
                'swh':'Total_Height'
}

DS=DS.rename_vars(grib2_rename_dic)
DS
#convert (u,v) in (amp,dir) or do the opposite?
# Out:
# <xarray.Dataset> Size: 784MB
# Dimensions:       (time: 24, y: 1286, x: 625)
# Coordinates:
#   * time          (time) datetime64[ns, UTC] 192B 2026-03-17 00:00:00+00:00 ....
#     latitude      (y, x) float64 6MB 34.8 34.79 34.78 34.77 ... 47.92 47.9 47.89
#     longitude     (y, x) float64 6MB -80.45 -80.42 -80.4 ... -40.84 -40.82 -40.8
# Dimensions without coordinates: y, x
# Data variables:
#     Total_Height  (time, y, x) float32 77MB nan nan nan ... 4.165 4.164 4.163
#     SW_period     (time, y, x) float32 77MB nan nan nan ... 8.144 8.987 9.829
#     v10           (time, y, x) float32 77MB nan nan nan nan ... 11.33 11.3 11.27
#     u10           (time, y, x) float32 77MB nan nan nan nan ... 1.497 1.55 1.602
#     SW_Height     (time, y, x) float32 77MB nan nan nan nan ... 2.03 2.039 2.049
#     SW_direction  (time, y, x) float32 77MB nan nan nan ... 250.2 251.5 252.8
#     Wind_U        (time, y, x) float64 154MB nan nan nan ... 8.466 8.486 8.504
#     Wind_V        (time, y, x) float64 154MB nan nan nan ... 7.68 7.621 7.563
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             cwao
#     GRIB_centreDescription:  Canadian Meteorological Service - Montreal
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             Canadian Meteorological Service - Montreal
#     history:                 2026-03-18T01:16 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
import numpy as np

# create 2 function to convert angle from math convention to geographical convention
# and reverse operation

def geo2math(angle_deg):
  '''angle in degreees,
  convert from geographic to mathematical angle
  '''
  return (90-angle_deg)%360


def math2geo(angle_deg):
  '''angle in degreees,
  convert from  mathematical to geographic angle
  '''
  return (90-angle_deg)%360




u=DS['Wind_U']
v=DS['Wind_V']

ampl=np.sqrt(u**2+v**2)
angle_rad=np.arctan2(v, u)#+np.pi
angle_deg=np.rad2deg(angle_rad)
angle_truenorth=math2geo(angle_deg)

DS['Wind_speed']=ampl
DS['Wind_direction']=angle_truenorth #this is in geographical convention 0=North, counting clockwise
DS
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:         (time: 24, y: 1286, x: 625)
# Coordinates:
#   * time            (time) datetime64[ns, UTC] 192B 2026-03-17 00:00:00+00:00...
#     latitude        (y, x) float64 6MB 34.8 34.79 34.78 ... 47.92 47.9 47.89
#     longitude       (y, x) float64 6MB -80.45 -80.42 -80.4 ... -40.82 -40.8
# Dimensions without coordinates: y, x
# Data variables:
#     Total_Height    (time, y, x) float32 77MB nan nan nan ... 4.165 4.164 4.163
#     SW_period       (time, y, x) float32 77MB nan nan nan ... 8.144 8.987 9.829
#     v10             (time, y, x) float32 77MB nan nan nan ... 11.33 11.3 11.27
#     u10             (time, y, x) float32 77MB nan nan nan ... 1.497 1.55 1.602
#     SW_Height       (time, y, x) float32 77MB nan nan nan ... 2.03 2.039 2.049
#     SW_direction    (time, y, x) float32 77MB nan nan nan ... 250.2 251.5 252.8
#     Wind_U          (time, y, x) float64 154MB nan nan nan ... 8.466 8.486 8.504
#     Wind_V          (time, y, x) float64 154MB nan nan nan ... 7.68 7.621 7.563
#     Wind_speed      (time, y, x) float64 154MB nan nan nan ... 11.43 11.41 11.38
#     Wind_direction  (time, y, x) float64 154MB nan nan nan ... 47.79 48.07 48.35
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             cwao
#     GRIB_centreDescription:  Canadian Meteorological Service - Montreal
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             Canadian Meteorological Service - Montreal
#     history:                 2026-03-18T01:16 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
#convert amplitude, direction to u,v (polar to cartesian)
ampl=DS['Wind_speed']
angle_deg=DS['Wind_direction']
angle_truemath=geo2math(angle_deg)
angle_rad=np.deg2rad(angle_deg)#+np.pi

u=ampl*np.cos(angle_rad)
v=ampl*np.sin(angle_rad)


##check if reprojection formula give good speed in cartesion
error=np.abs(DS['Wind_U']-u + (DS['Wind_V']-v) )

print(f'wind speed minvalue is {ampl.min().values}')
print(f'max reprojection error is {error.max().values}')

####ok! nice :)
# Out:
# wind speed minvalue is 0.021512916783065543
# max reprojection error is 3.907985046680551e-14

# %%
key=list(DS.keys())#[0]
print(key)


# 2Dmap at given time
ds_2d=DS.isel(time=2)

# Create a figure and an axes object with a PlateCarree projection
plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())


ds_2d[key[-2]].plot( ax=ax,
            transform=ccrs.PlateCarree(),
            x='longitude',
            y='latitude',
            cmap='viridis',
            cbar_kwargs={'label': [key[-2]],
                          'orientation' : 'horizontal'})
# Out:
# ['Total_Height', 'SW_period', 'v10', 'u10', 'SW_Height', 'SW_direction', 'Wind_U', 'Wind_V', 'Wind_speed', 'Wind_direction']

# %%
          # compare model and observations

# %%
stations
# Out:
#    #IATA            FR name            EN name Province AUTO/MAN  Latitude  \
# 25          BANQUEREAU BANK    BANQUEREAU BANK       XX     AUTO   44.2402
# 27        EAST SCOTIA SLOPE  EAST SCOTIA SLOPE       XX     AUTO   42.2613
# 28          HALIFAX HARBOUR    HALIFAX HARBOUR       XX     AUTO   44.5017
# 29             LA HAVE BANK       LA HAVE BANK       XX     AUTO   42.5047
#
#     Longitude Elevation # ICAO    # WMO    # MSC DST Time STD Time  \
# 25   -57.1032         0         4400139  9300243
# 27   -61.9985         0         4400137  9300355
# 28   -63.4026         0         4400258  9300400
# 29   -64.0718         0         4400150  9300450
#
#                                         Data Provider  \
# 25  Environment and Climate Change Canada (ECCC) i...
# 27  Environment and Climate Change Canada (ECCC) i...
# 28  Environment and Climate Change Canada (ECCC) i...
# 29  Environment and Climate Change Canada (ECCC) i...
#
#                         Data Attribution Notice
# 25  Data provided by ECCC. All rights reserved.
# 27  Data provided by ECCC. All rights reserved.
# 28  Data provided by ECCC. All rights reserved.
# 29  Data provided by ECCC. All rights reserved.

# %%
buoy_id = int(buoy_ids[0])

buoy_info = stations[stations['# WMO'] == str(buoy_id)]
buoy_lat = buoy_info['Latitude'].iloc[0]
buoy_lon = buoy_info['Longitude'].iloc[0]

print(f"Selected buoy ID: {buoy_id}")
print(f"Latitude is: {buoy_lat}")
print(f"Longitude is : {buoy_lon}")
# Out:
# Selected buoy ID: 4400137
# Latitude is: 42.2613
# Longitude is : -61.9985

# %%
ds_buoy.sel(buoy_id=buoy_id)
# Out:
# <xarray.Dataset> Size: 1kB
# Dimensions:         (time: 24)
# Coordinates:
#   * time            (time) datetime64[ns, UTC] 192B 2026-03-17 00:05:00+00:00...
#     buoy_id         int64 8B 4400137
#     lat             float64 8B 42.26
#     lon             float64 8B -62.0
# Data variables:
#     SW_Height       (time) float64 192B 2.4 2.5 2.1 2.4 2.6 ... 5.0 4.3 5.1 4.9
#     SW_period       (time) float64 192B 6.6 7.1 6.7 7.1 7.0 ... 9.5 9.2 9.6 9.7
#     SW_direction    (time) int64 192B 157 175 156 172 173 ... 185 184 197 178
#     Wind_speed      (time) float64 192B 10.81 9.611 9.306 ... 13.0 8.611 7.806
#     Wind_direction  (time) int64 192B 348 348 350 9 359 9 ... 12 6 4 5 104 96

# %%
#import numpy as np # Import numpy for numerical operations

def nearest_index(ds,location):
    #
    #see maps here https://eccc-msc.github.io/msc-animet/
    #see https://stackoverflow.com/questions/58758480/xarray-select-nearest-lat-lon-with-multi-dimension-coordinates
    idx=[]
    idy=[]
    for loca in location:
        lat,lon=loca
        d_lat = ds.latitude - lat
        d_lon = ds.longitude - lon
        r2 = d_lat**2 + d_lon**2
        i_j_loc = np.where(r2 == np.min(r2))
        idx.append(i_j_loc[1])
        idy.append(i_j_loc[0])
    #
    #put in the right format: a list of number
    idx=np.array(idx).flatten().tolist()
    idy=np.array(idy).flatten().tolist()
    return (idy,idx)

#iy,ix=nearest_index(DS_cropped,[[buoy_lat,buoy_lon]])
iy,ix=nearest_index(DS,stations[['Latitude','Longitude']].values)
#print(iy,ix)

# Interpolate and assign 'buoy_id' as the new dimension
ds_extract = DS.interp(y=('buoy_id', iy), x=('buoy_id', ix))
ds_extract.coords['buoy_id'] = stations['# WMO'].values.astype(int)
#ds_extract.drop_vars(['latitude','longitude'])
#ds_extract

ds_extract.sel(buoy_id=buoy_id)
# Out:
# <xarray.Dataset> Size: 2kB
# Dimensions:         (time: 24)
# Coordinates:
#   * time            (time) datetime64[ns, UTC] 192B 2026-03-17 00:00:00+00:00...
#     latitude        float64 8B 42.25
#     longitude       float64 8B -62.0
#     buoy_id         int64 8B 4400137
# Data variables:
#     Total_Height    (time) float64 192B 2.903 3.018 3.132 ... 6.094 6.009 5.803
#     SW_period       (time) float64 192B 7.473 7.53 7.613 ... 11.04 11.89 nan
#     v10             (time) float64 192B 7.654 8.112 8.471 ... 12.83 10.42 4.321
#     u10             (time) float64 192B -10.98 -11.22 -10.93 ... 2.305 6.349
#     SW_Height       (time) float64 192B 2.887 3.012 3.127 ... 6.094 4.138 nan
#     SW_direction    (time) float64 192B 160.2 162.8 164.7 ... 196.7 229.4 nan
#     Wind_U          (time) float64 192B -3.435 -3.323 -2.864 ... 8.495 7.637
#     Wind_V          (time) float64 192B 12.94 13.44 13.53 ... 9.963 6.464 -0.806
#     Wind_speed      (time) float64 192B 13.39 13.85 13.83 ... 12.83 10.68 7.68
#     Wind_direction  (time) float64 192B 345.1 346.1 348.0 ... 39.04 52.73 96.02
#     y               int64 8B 630
#     x               int64 8B 350
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             cwao
#     GRIB_centreDescription:  Canadian Meteorological Service - Montreal
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             Canadian Meteorological Service - Montreal
#     history:                 2026-03-18T01:16 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
i=0
buoy_id=int(buoy_ids[i])
#print(stations.sort_values(by='# WMO'))
stations=stations.sort_values(by='# WMO')
stations_name=stations['EN name'].to_list()

print(buoy_ids[i])
print(stations_name[i])
fig, ax = plt.subplots(5, 1, figsize=(10, 16))

j=0
for key in list(ds_buoy.keys())[::-1]:
  #print(key)
  ax[j].plot(ds_extract['time'],ds_extract.sel(buoy_id=buoy_id)[key],label='model')
  ax[j].plot(ds_buoy['time'],ds_buoy.sel(buoy_id=buoy_id)[key],label='observation')
  ax[j].set_title(key)
  ax[j].legend()
  j=j+1
# Out:
# 4400137
# EAST SCOTIA SLOPE

# %%
#https://www.ndbc.noaa.gov/faq/measdes.shtml#stdmet
#for buoy Wind direction is direction 'coming from' in degrees clockwise from true N
#issue with wind direction
# for model, wind direction is where the wind goes!!!!!! opposite direction of 'coming from' direction

i=0

print(buoy_ids[i])
print(stations_name[i])

buoy_id=int(buoy_ids[i])
ww=ds_buoy.sel(buoy_id=buoy_id)[key]
#ww=(180+ ww)%360 #ok I implemented it when loading buoy data

key='Wind_direction'
fig,ax=plt.subplots()
ax.plot(ds_extract['time'],ds_extract.sel(buoy_id=buoy_id)[key],label='model')
ax.plot(ds_buoy['time'],ww,label='observation')
ax.legend()



ds_extract.sel(buoy_id=buoy_id)[key].values[:10]-ww.values[:10]
# Out:
# 4400137
# EAST SCOTIA SLOPE
# array([342.73324192, 343.61647989, 345.94510402, 347.06064641,
#        348.90931033, 353.41780027, 355.85223998, 354.87883833,
#         -2.4436419 , 356.15167511])

# %%
try:
    import filterpy
    print("filterpy is already installed.")
except ImportError:
    print("Installing filterpy...")
    # !pip install filterpy
    print("filterpy installed.")

import numpy as np
from filterpy.kalman import KalmanFilter
from filterpy.kalman import ExtendedKalmanFilter

buoy_id = int(buoy_ids[0])
observed_data = ds_buoy.sel(buoy_id=buoy_id)
forecast_data = ds_extract.sel(buoy_id=buoy_id)

print(f"Selected Buoy ID: {buoy_id}")
print('\n\n')

print("Observed Data for Selected Buoy:")
print(observed_data)

print('\n\n')

print("\nForecast Data for Selected Buoy:")
print(forecast_data)
# Out:
# filterpy is already installed.
# Selected Buoy ID: 4400137
#
#
#
# Observed Data for Selected Buoy:
# <xarray.Dataset> Size: 1kB
# Dimensions:         (time: 24)
# Coordinates:
#   * time            (time) datetime64[ns, UTC] 192B 2026-03-17 00:05:00+00:00...
#     buoy_id         int64 8B 4400137
#     lat             float64 8B 42.26
#     lon             float64 8B -62.0
# Data variables:
#     SW_Height       (time) float64 192B 2.4 2.5 2.1 2.4 2.6 ... 5.0 4.3 5.1 4.9
#     SW_period       (time) float64 192B 6.6 7.1 6.7 7.1 7.0 ... 9.5 9.2 9.6 9.7
#     SW_direction    (time) int64 192B 157 175 156 172 173 ... 185 184 197 178
#     Wind_speed      (time) float64 192B 10.81 9.611 9.306 ... 13.0 8.611 7.806
#     Wind_direction  (time) int64 192B 348 348 350 9 359 9 ... 12 6 4 5 104 96
#
#
#
#
# Forecast Data for Selected Buoy:
# <xarray.Dataset> Size: 2kB
# Dimensions:         (time: 24)
# Coordinates:
#   * time            (time) datetime64[ns, UTC] 192B 2026-03-17 00:00:00+00:00...
#     latitude        float64 8B 42.25
#     longitude       float64 8B -62.0
#     buoy_id         int64 8B 4400137
# Data variables:
#     Total_Height    (time) float64 192B 2.903 3.018 3.132 ... 6.094 6.009 5.803
#     SW_period       (time) float64 192B 7.473 7.53 7.613 ... 11.04 11.89 nan
#     v10             (time) float64 192B 7.654 8.112 8.471 ... 12.83 10.42 4.321
#     u10             (time) float64 192B -10.98 -11.22 -10.93 ... 2.305 6.349
#     SW_Height       (time) float64 192B 2.887 3.012 3.127 ... 6.094 4.138 nan
#     SW_direction    (time) float64 192B 160.2 162.8 164.7 ... 196.7 229.4 nan
#     Wind_U          (time) float64 192B -3.435 -3.323 -2.864 ... 8.495 7.637
#     Wind_V          (time) float64 192B 12.94 13.44 13.53 ... 9.963 6.464 -0.806
#     Wind_speed      (time) float64 192B 13.39 13.85 13.83 ... 12.83 10.68 7.68
#     Wind_direction  (time) float64 192B 345.1 346.1 348.0 ... 39.04 52.73 96.02
#     y               int64 8B 630
#     x               int64 8B 350
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             cwao
#     GRIB_centreDescription:  Canadian Meteorological Service - Montreal
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             Canadian Meteorological Service - Montreal
#     history:                 2026-03-18T01:16 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
forecast_data['time'].isel(time=i).values # this is a datetime
#forecast_data['time'].values[i] # this is nanoseconds
# Out:
# np.datetime64('2026-03-17T00:00:00.000000000')

# %%
#####Kalman filtering test with one dimension
############### THIS IS filtering only ! state= x
############### To create forecast , state muste be state=[x, xprime]!!!!

#let says next x=x+dt*vel where vel=slope=derivate relatively to time
i=2

print(buoy_ids[i])
print(stations_name[i])

buoy_id=int(buoy_ids[i])

observed_data = ds_buoy.sel(buoy_id=buoy_id)
forecast_data = ds_extract.sel(buoy_id=buoy_id)

num_steps=24
end_step=16 #end of observations ;

key='Wind_speed' #i.e. features
observations = observed_data[key].values
forecasts = forecast_data[key].values


# test for extended kalman filter Define the measurement function h(x) and its Jacobian H
# Assuming measurement z is directly the state x (i.e., h(x) = x)
# def hx(x):
#     return x

# # Jacobian of h(x) = x is the identity matrix
# def HJacobian_func(x):
#     return np.eye(n)

# Assign these functions to the Kalman filter object
#kf.Hx = hx
#kf.HJacobian = HJacobian_func

# state transition model (how the system evolves)
# measurement model (how observations relate to the state).
# increasing

#initiation
P_0 = 100 #initial state covariance
F = 1 #state transition model
H = 1 #observation model
Q = np.nanvar(np.diff(forecasts[:end_step])) #process error covariance
#R = np.nanvar(np.diff(observations[:end_step])) #measurment error covariance
R = .1*np.nanvar(observations[:end_step] - forecasts[:end_step],axis=0) #measurement noise covariance
# Q and R are one of the major difficulties !!!

print(f"Initial State Covariance (P_0): {P_0}")
print(f"State Transition Model (F): {F}")
print(f"Observation Model (H): {H}")
print(f"Process Noise Covariance (Q): {Q}")
print(f"Measurement Noise Covariance (R): {R}")


# Instantiate a KalmanFilter object
kf = KalmanFilter(dim_x=1, dim_z=1) # dim_x is the dimension of the state, dim_z is the dimension of the measurement

# Initialize Kalman filter
kf.P = np.array([P_0]) # Initial state covariance
kf.F = np.array([F])  # State transition matrix
kf.H = np.array([[H]])  # Measurement function # 'convert state int measurement'
kf.Q = np.array([[Q]])  # Process noise covariance
kf.R = np.array([[R]])  # Measurement noise covariance


#store the Kalman-filtered estimates
kf_states = []
kf_times = []

for i in range(num_steps):

    # Update the predicted state (kf.x) to be the current forecast
    kf.x = np.array(forecasts[i])


    # Kalman filter prediction based on previous state
    kf.predict()


    # Kalman Filter update with measurement
    if i < end_step:#len(observations):
      obs_actual = observations[i]
      kf.update(np.array(obs_actual))# update only if obs


    kf_states.append(kf.x)
    kf_times.append(forecast_data['time'].isel(time=i).values)


#print(kf.x)
#print(kf_states[0:4])


fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(forecast_data['time'], forecasts, label='Model Forecast', marker='o', linestyle='-')
ax.plot(observed_data['time'], observations, label='Observations', marker='x', linestyle='--')
ax.plot(kf_times, kf_states, label='Filtered Forecast', marker='s', linestyle='-.')

# Plot vertical line showing 'end of observations'
plt.axvline(x=kf_times[end_step], color='r', linestyle='--', linewidth=2)
ax.text(kf_times[end_step],np.max(forecasts),'Obs. end for Kalman filter')

ax.set_title(f'Kalman Filtered Forecast vs. Observations for Buoy {buoy_id}')
ax.set_xlabel('Time')
ax.set_ylabel('Wind speed (m/s)')
ax.legend(loc='upper left')


# Auto-format x-axis dates to prevent overlap
fig.autofmt_xdate()

print('Forecasts are NOT corrected after end of observation!')
# Out:
# 4400150
# LA HAVE BANK
# Initial State Covariance (P_0): 100
# State Transition Model (F): 1
# Observation Model (H): 1
# Process Noise Covariance (Q): 0.8288061309308676
# Measurement Noise Covariance (R): 0.3029913327270112
# Forecasts are NOT corrected after end of observation!

# %%
#### consider some virtual observation after end of observation
#### !!!! trying a trick


# Instantiate a KalmanFilter object
kf = KalmanFilter(dim_x=1, dim_z=1) # dim_x is the dimension of the state, dim_z is the dimension of the measurement

# Initialize Kalman filter
kf.P = np.array([P_0]) # Initial state covariance
kf.F = np.array([F])  # State transition matrix
kf.H = np.array([[H]])  # Measurement function # 'convert state int measurement'
kf.Q = np.array([[Q]])  # Process noise covariance
kf.R = np.array([[R]])  # Measurement noise covariance


#store the Kalman-filtered estimates
kf_states = []
kf_times = []

for i in range(num_steps):

    # Update the predicted state (kf.x) to be the current forecast
    kf.x = np.array(forecasts[i])

    # Kalman filter prediction based on previous state
    kf.predict()

    # Kalman Filter update with measurement
    if i < end_step:#len(observations):
      obs_actual = observations[i]
      kf.update(np.array(obs_actual))# update only if obs
    else:
      wei_obs=1/(1+i-end_step)# this is not the best 1/m is harsh # just to try something
      kf.update(np.array(
                np.nansum(
                    [obs_actual *wei_obs,  kf.x[0]]
                    )/(1+wei_obs)
                    )
                    ) # here I update mix last obs+forecast


    kf_states.append(kf.x)
    kf_times.append(forecast_data['time'].isel(time=i).values)



fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(forecast_data['time'], forecasts, label='Model Forecast', marker='o', linestyle='-')
ax.plot(observed_data['time'], observations, label='Observations', marker='x', linestyle='--')
ax.plot(kf_times, kf_states, label='Filtered Forecast', marker='s', linestyle='-.')

# Plot vertical line showing 'end of observations'
plt.axvline(x=kf_times[end_step], color='r', linestyle='--', linewidth=2)
ax.text(kf_times[end_step],np.max(forecasts),'Obs. end for Kalman filter')

ax.set_title(f'Kalman Filtered Forecast vs. Observations for Buoy {buoy_id}')
ax.set_xlabel('Time')
ax.set_ylabel('Wind speed (m/s)')
ax.legend(loc='upper left')


# Auto-format x-axis dates to prevent overlap
fig.autofmt_xdate()

# %%
### create a multi sensor kalman filter of degree 0, meaning # degree1 is x'=x+v*deltat
#############THIS IS FILTER ########
###### no clear relation between one step and the next one
#see tuto here https://cocalc.com/share/public_paths/7557a5ac1c870f1ec8f01271959b16b49df9d087/06-Multivariate-Kalman-Filters.ipynb


def KF_order0(observed_data,forecast_data,keys,end_step):

  n=len(keys)
  num_steps=forecast_data.sizes['time']
  # Instantiate a KalmanFilter object
  kf = KalmanFilter(dim_x=n, dim_z=n) # dim_x is the dimension of the state, dim_z is the dimension of the measurement
  #kf = ExtendedKalmanFilter(dim_x=n, dim_z=n)

  forecasts=forecast_data.to_dataframe()[keys].values
  observations=observed_data.to_dataframe()[keys].values

  #initiation values
  P_0 = np.diag([0.1]*n) #initial state covariance ; recompute this to have something like 5% of var mean amplitude
  F = np.diag([1]*n) #state transition model
  H = F #observation model - no longer needed if Hx and HJacobian are used for EKF
  Q = np.nanvar(np.diff(forecasts[:end_step],axis=0),axis=0) #process noise covariance
  R = 1*np.nanvar(observations[:end_step] - forecasts[:end_step],axis=0) #measurement noise covariance
  #print(Q)#Q give a list of number. length is number of variables(keys)
  Q=np.diag(Q)
  R=np.diag(R)

  # Initialize Kalman filter
  kf.P = np.array(P_0) # Initial state covariance
  kf.F = np.array(F)  # State transition matrix (x_new=F*x)
  kf.H = np.array(H)  # Measurement function - no longer needed if EKF when Hx and HJacobian are set
  kf.Q = np.array(Q)  # Process noise covariance
  kf.R = np.array(R)  # Measurement noise covariance


  #store the Kalman-filtered estimates
  kf_states = []
  kf_times = []

  for i in range(num_steps):

      # Update the predicted state (kf.x) to be the current forecast
      kf.x = np.array(forecasts[i])

      # Kalman filter prediction based on previous state
      kf.predict()



      # Kalman Filter update using the observation
      if i < end_step:#len(observations):# update only if obs
        obs_actual = observations[i]
        kf.update(np.array(obs_actual),
                  #kf.HJacobian,kf.Hx
                  )
      else:
        wei_obs=1/(1+i-end_step)# this is not the best 1/m is harsh
        kf.update(np.array(
                  np.nansum(
                      [obs_actual *wei_obs,  kf.x],axis=0
                      )/(1+wei_obs)
                      ),
                 # kf.HJacobian, kf.Hx
                  )

      kf_states.append(kf.x)
      kf_times.append(forecast_data['time'].isel(time=i).values)
      # save new covariance kf.P ?#

  kf_states=np.vstack(kf_states)
  #print(kf.F)

  return kf_states,kf_times


def KF_figure(observed_data,forecast_data,kf_states,kf_times,keys):

  n=kf_states.shape[1]


  buoy_id =forecast_data.buoy_id.values

  fig, ax = plt.subplots(n,figsize=(12, 4*n))
  if n==1:
    #print('oneplot')
    ax.plot(forecast_data['time'], forecast_data[keys[0]], label='Model Forecast', marker='o', linestyle='-')
    ax.plot(observed_data['time'], observed_data[keys[0]], label='Observations', marker='x', linestyle='--')
    ax.plot(kf_times, kf_states, label='Filtered Forecast', marker='s', linestyle='-.')

    # Plot vertical line showing 'end of observations'
    plt.axvline(x=kf_times[end_step], color='r', linestyle='--', linewidth=2)
    ax.text(kf_times[end_step],ax.get_ylim()[1]*.95,'Obs. end for Kalman filter')

    ax.set_title(f'Kalman Filtered Forecast vs. Observations for Buoy {buoy_id}')
    ax.set_xlabel('Time')
    ax.set_ylabel(keys[0])
    ax.legend(loc='upper left')

  else:
    for i in range(n):
      ax[i].plot(forecast_data['time'], forecast_data[keys[i]], label='Model Forecast', marker='o', linestyle='-')
      ax[i].plot(observed_data['time'], observed_data[keys[i]], label='Observations', marker='x', linestyle='--')
      ax[i].plot(kf_times, kf_states[:,i], label='Filtered Forecast', marker='s', linestyle='-.')

      # Plot vertical line showing 'end of observations'
      ax[i].axvline(x=kf_times[end_step], color='r', linestyle='--', linewidth=2)
      ax[i].text(kf_times[end_step],ax[i].get_ylim()[1]*.95,'Obs. end for Kalman filter')

      if i==0:
        ax[i].set_title(f'Kalman Filtered Forecast vs. Observations for Buoy {buoy_id}')

      ax[i].set_xlabel('Time')
      ax[i].set_ylabel(keys[i])
      ax[i].legend(loc='upper left')


  # Auto-format x-axis dates to prevent overlap
  fig.autofmt_xdate()

  return fig

# %%
 ###############test if KF_multidim give the same as previous test, wih one variable

keys=['Wind_speed','Wind_direction','SW_Height','SW_direction','SW_period']

i=1
buoy_id=int(buoy_ids[i])
print(buoy_ids[i])
print(stations_name[i])

observed_data = ds_buoy.sel(buoy_id=buoy_id)
forecast_data = ds_extract.sel(buoy_id=buoy_id)

kf_states=[]
for key in keys:
  kf_state,kf_times  = KF_order0(observed_data,forecast_data,[key],end_step)
  kf_states.append(kf_state)

kf_states=np.hstack(kf_states)
figur=KF_figure(observed_data,forecast_data,kf_states,kf_times,keys)

figur.axes[0].set_title('Kalman filter, order0 - '+ stations_name[i])
figur.savefig('test_kf_order0.jpg')
# Out:
# 4400139
# BANQUEREAU BANK

# %%
#####consider multiples variables!
# ... nan in forecast for one variable seems to propagate to others

# do one buoy ; all keys/features
i=3
buoy=buoy_ids[i]
end_step=16 #end of observations for Kalman filter;


print(buoy_ids[i])
print(stations_name[i])
buoy=int(buoy)
observed_data = ds_buoy.sel(buoy_id=buoy)
forecast_data = ds_extract.sel(buoy_id=buoy)
kf_states,kf_times  = KF_order0(observed_data,forecast_data,keys,end_step)
figur=KF_figure(observed_data,forecast_data,kf_states,kf_times,keys)

figur.axes[0].set_title('Kalman filter, order0 - '+ stations_name[i])
# Out:
# 4400258
# HALIFAX HARBOUR
# Text(0.5, 1.0, 'Kalman filter, order0 - HALIFAX HARBOUR')

# %%
### Adding variable can false one variable results.... usual kalman not adapted?
#Kalman Filter only works when the state space model (i.e. state transition function) is linear!!!!!
## which is not the case here!
# however measurement matrix H is not clearly known! so how to do the extended version???

# ... nan in forecast for one variable seems to propagate to others

# %%
from filterpy.common import Q_discrete_white_noise
Q_discrete_white_noise(dim=2, dt=1, var=np.nanvar(np.diff(forecasts)))
# Out:
# array([[0.54480772, 1.08961544],
#        [1.08961544, 2.17923087]])

# %%
            #PREDICTION!!!!

#### test code and initiation matrixes here,

##################### kalman for PREDICTION!!! state=[x,xprime]
#####let say I have x only in observation, and not xprime ; I will maybe add it later
# xpredict=xprime*dt+x
#xprime_predict=xprime # same derivate, for simplicity

dt=60*60 # convert 1hour in seconds

i=3
buoy_id = int(buoy_ids[i])

observed_data = ds_buoy.sel(buoy_id=buoy_id)
forecast_data = ds_extract.sel(buoy_id=buoy_id)
print(buoy_ids[i])
print(stations_name[i])

num_steps=24
end_step=16 #end of observations ;

key='Wind_speed' #i.e. features
observations = observed_data[key].values
forecasts = forecast_data[key].values

#initiation
a=np.nanvar(np.diff(forecasts))
P_0 = np.diag([500, 500/dt]) #initial state covariance
F = [[1,dt],[0,1]] #state transition model, should be 2x2
H = [[1,0]] #observation model, should be 1x2 (measurement is x, state is [x, xprime]), xprime not measured
Q = np.diag([a,a/dt]) #process noise covariance (2x2)
R = .1*np.array([[np.nanvar(observations[:end_step] - forecasts[:end_step])]])  # measurement noise covariance (1x1), as dim_z=1


# Remove the simplified scalar assignments for P, R, Q as they overwrite correct matrix definitions.
#P=.1
#R=0.
#Q=.1

print(f"Initial State Covariance (P_0): {P_0}")
print(f"State Transition Model (F): {F}")
print(f"Observation Model (H): {H}")
print(f"Process Noise Covariance (Q): {Q}")
print(f"Measurement Noise Covariance (R): {R}")


# Instantiate a KalmanFilter object
##Let say state= [position,slope] BUT only position is measurerd
kf = KalmanFilter(dim_x=2, dim_z=1) # dim_x is the dimension of the state, dim_z is the dimension of the measurement

# Initialize Kalman filter
kf.P = P_0 # Initial state covariance
kf.F = np.array(F)  # State transition matrix (2x2)
kf.H = np.array(H)  # Measurement function (1x2)
kf.Q = Q  # Process noise covariance (2x2)
kf.R = R  # Measurement noise covariance (1x1)




#store the Kalman-filtered estimates
kf_states = []
kf_cov = []
kf_times = []

for i in range(num_steps-1):

    # Update the predicted state (kf.x) to be the current forecast
    slope=(forecasts[i+1]-forecasts[i])/dt
    kf.x = np.array([forecasts[i],slope])

    # Kalman filter prediction based state
    kf.predict()


    # Kalman Filter update using the observation
    if i < end_step:#len(observations): # update only if obs
      obs_actual = observations[i]
      kf.update(np.array([obs_actual]))

    kf_states.append(kf.x[0]) #? # kf.x is now a 2-element array [x, xprime]
    kf_cov.append(kf.P[0]) #? # kf.P is now a 2x2 matrix
    kf_times.append(forecast_data['time'].isel(time=i).values)




fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(forecast_data['time'], forecasts, label='Model Forecast', marker='o', linestyle='-')
ax.plot(observed_data['time'], observations, label='Observations', marker='x', linestyle='--')
ax.plot(kf_times, kf_states, label='Filtered Forecast', marker='s', linestyle='-.')

# Plot vertical line showing 'end of observations'
plt.axvline(x=kf_times[end_step], color='r', linestyle='--', linewidth=2)
ax.text(kf_times[end_step],np.max(forecasts),'Obs. end for Kalman filter')

ax.set_title(f'Kalman Filtered Forecast vs. Observations for Buoy {buoy_id}')
ax.set_xlabel('Time')
ax.set_ylabel('Wind speed (m/s)')
ax.legend(loc='upper left')


# Auto-format x-axis dates to prevent overlap
fig.autofmt_xdate()
# Out:
# 4400258
# HALIFAX HARBOUR
# Initial State Covariance (P_0): [[5.00000000e+02 0.00000000e+00]
#  [0.00000000e+00 1.38888889e-01]]
# State Transition Model (F): [[1, 3600], [0, 1]]
# Observation Model (H): [[1, 0]]
# Process Noise Covariance (Q): [[6.71689691e-01 0.00000000e+00]
#  [0.00000000e+00 1.86580470e-04]]
# Measurement Noise Covariance (R): [[0.07405152]]

# %%
def KF_order1(observed_data,forecast_data,key,end_step):
# main change is that now transition model link one time with next one
# use x(t+1)=x(t)+slope*dt

  dt=1#60*60 # to recode whit diff(forecasts.time).unique()_toseconds smthg like that
  #!!!! I think, not sure, that dt is a numerical step; not the number of second
  # if 60*60, then filtered forecast is always equal to observations!
  forecasts=forecast_data.to_dataframe()[key].values
  observations=observed_data.to_dataframe()[key].values

  num_steps=forecast_data.sizes['time']
  # Instantiate a KalmanFilter object
  kf = KalmanFilter(dim_x=2, dim_z=1) # dim_x is the dimension of the state, dim_z is the dimension of the measurement
  #kf = ExtendedKalmanFilter(dim_x=n, dim_z=n)


  #initiation
  a=np.nanvar(np.diff(forecasts))
  P_0 = np.diag([500, 500/dt]) #initial state covariance
  F = [[1,dt],[0,1]] #state transition model, should be 2x2
  H = [[1,0]] #observation model, should be 1x2 (measurement is x, state is [x, xprime]), xprime not measured
  Q = np.diag([a,a/dt]) #process noise covariance (2x2)
  R = 1*np.array([[np.nanvar(observations[:end_step] - forecasts[:end_step])]])  # measurement noise covariance (1x1), as dim_z=1



  # Initialize Kalman filter
  kf.P = P_0 # Initial state covariance
  kf.F = np.array(F)  # State transition matrix (2x2)
  kf.H = np.array(H)  # Measurement function (1x2)
  kf.Q = Q  # Process noise covariance (2x2)
  kf.R = R  # Measurement noise covariance (1x1)


  #store the Kalman-filtered estimates
  kf_states = []
  kf_times = []
  kf_cov = []

  for i in range(num_steps-1):

      # Update the predicted state (kf.x) to be the current forecast
      slope=(forecasts[i+1]-forecasts[i])/dt
      kf.x = np.array([forecasts[i],slope])

      # Kalman filter prediction based state
      kf.predict()

      # Kalman Filter update using the observation
      if i < end_step:#len(observations): # update only if obs
        obs_actual = observations[i]
        kf.update(np.array([obs_actual]))

      kf_states.append(kf.x[0]) #? # kf.x is now a 2-element array [x, xprime]
      kf_times.append(forecast_data['time'].isel(time=i).values)
      #kf_cov.append(kf.P[0]) #? # kf.P is now a 2x2 matrix #see later


  #kf_states=np.array([np.hstack(kf_states)])
  kf_states=np.vstack(kf_states)
  #print(kf.F)

  return kf_states,kf_times

kf_states,kf_times  = KF_order1(observed_data,forecast_data,key,end_step)

# %%
# do all buoys ; all keys/features
keys=['Wind_speed','Wind_direction','SW_Height','SW_direction','SW_period']
end_step=16 #end of observations for Kalman filter;

#for buoy in buoy_ids[1:3] :
i=0
buoy=buoy_ids[i]
print(f'Buoy {buoy}')
buoy=int(buoy)
observed_data = ds_buoy.sel(buoy_id=buoy)
forecast_data = ds_extract.sel(buoy_id=buoy)

kf_states=[]
for key in keys:
  kf_state,kf_times  = KF_order1(observed_data,forecast_data,key,end_step)
  kf_states.append(kf_state)

kf_states=np.hstack(kf_states)
figur=KF_figure(observed_data,forecast_data,kf_states,kf_times,keys)

figur.axes[0].set_title('Kalman filter, order1 - '+ stations_name[i])

figur.savefig('test_kf_order1.jpg')
#
# Out:
# Buoy 4400137

# %%
kf_states=[]
for key in keys:
  kf_state,kf_times  = KF_order0(observed_data,forecast_data,[key],end_step)
  kf_states.append(kf_state)

kf_states=np.hstack(kf_states)
figur=KF_figure(observed_data,forecast_data,kf_states,kf_times,keys)

figur.axes[0].set_title('Kalman filter, order0 - '+ stations_name[i])
figur.savefig('test_kf_order0.jpg')
